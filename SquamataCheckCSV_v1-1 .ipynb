# %% [markdown]
# # SquamataCheckCSV - Jupyter notebook for reading in CSV files and checking Min Max
#
# ### Version 1.1
#
# This Jupyter Notebook performs the following operations:
# - Loads a CSV file.
# - Calculates Min and Max for each channel and prints output.
#
#
# ### To execute a function/command select a cell and Hold-Shift + Press-Enter
#
# **The 'r' signifies a string literal. Use for paths.**
#
# - v1.0: Read csv File into pandas, Create Array of csv column headers, assign header array of channel descriptions and units.
# - v1.1: clean up comments andd help 5-14-2020

# %%
# Phil Brown (pbrown@usgs.gov) 2020 Beta
# Working Python 3 Notebook used to facilitate the release of Airborn Magnetic Data to ScienceBase.  
# This notebook is used to read in CSV files, print out header values and print out the minimum and maximum od all data channels.

# %%
# Test Cell
print ("Jupyter is working.") #To run this cell, hold down Shift and press Enter.
# Out:
# Jupyter is working.

# %%
# Load required Libraries
import sys
import os
import zipfile
import csv
import requests
import shutil
from shutil import copyfile
import zipfile
import datetime
import glob
from lxml import etree
import json
import pickle
import shutil
import fileinput
import json
import pandas as pd
import numpy as np
from IPython.core.display import display
from lxml import etree
import re
from ipywidgets import *
from IPython.display import display
from IPython.html.widgets import widgets
import datetime
import dateutil.parser
import time
from IPython.display import Javascript

# %% [markdown]
# ## Please set directory paths below

# %%
#Set Data Paths - perhaps we'll get a user interface GUI to do this some day so the user doesn't have to change the code?
csvPath = r"C:\CurrentWork\HicksDomeIllinoisMagAndRad\Data" #The 'r' signifies a string literal. Use this syntax for for paths.
csvFileName = "USA_Hicks-Dome-Airborne-Survey-2019_MagneticData.csv"

# %%
#Concatenate strings and check path for the fun of it.
csvFilePath = csvPath + "\\" + csvFileName
print ('The CSV File Path is ' + csvFilePath)
# Out:
# The CSV File Path is C:\CurrentWork\HicksDomeIllinoisMagAndRad\Data\USA_Hicks-Dome-Airborne-Survey-2019_MagneticData.csv

# %% [markdown]
# ## Lets now import and index values from the CSV file

# %%
# read file into pandas; note that can take over 1 minute depending on the size of the CSV file and computing power.

magDataFrame = pd.read_csv(csvFilePath, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
magDataFrame
# Out:
#               baltl      baltlc       barom         baseA        baseAo  \
# 0        223.079773  223.051712  223.051712  51005.378906  51005.539062
# 1        222.926331  222.932938  222.932938  51005.378906  51005.539062
# 2        222.772888  222.814163  222.814163  51005.378906  51005.539062
# 3        222.619446  222.695404  222.695404  51005.378906  51005.539062
# 4        222.466003  222.576630  222.576630  51005.378906  51005.539062
# 5        222.312561  222.457855  222.457855  51005.378906  51005.539062
# 6        222.159134  222.339081  222.339081  51005.378906  51005.535156
# 7        222.005692  222.220306  222.220306  51005.378906  51005.535156
# 8        221.852249  222.101547  222.101547  51005.378906  51005.535156
# 9        221.698807  221.982773  221.982773  51005.378906  51005.535156
# 10       221.545364  221.863998  221.863998  51005.378906  51005.535156
# 11       221.452271  221.711243  221.711243  51005.378906  51005.535156
# ...

# %%
# now get an array of the header names and print them out.
magHeaderList = list(magDataFrame.columns.values)
##magHeaderList
for i in range(len(magHeaderList)):
 print (str(i) + ',' + magHeaderList[i])
# Out:
# 0,baltl
# 1,baltlc
# 2,barom
# 3,baseA
# 4,baseAo
# 5,date
# 6,directn
# 7,drape
# 8,DTMc
# 9,DTMo
# 10,fid10
# 11,fiducial
# 12,flt
# 13,hgps
# 14,jul_day
# 15,lat
# 16,latitude
# 17,line
# 18,line_no
# 19,lon
# 20,longitud
# 21,m3l
# 22,mfluxX
# 23,mfluxY
# 24,mfluxZ
# 25,mreslc
# 26,mreslcb
# 27,mreslct
# 28,mreslvl
# 29,mreslvld
# 30,mreslvldi
# 31,radar
# 32,raltl
# 33,raltlc
# 34,resmag
# 35,topoSRTM
# 36,totmag
# 37,um3l
# 38,x
# 39,y
# 40,year
# 41,z

# %% [markdown]
# ## Calculate Min Max and print result

# %%
#Calculate Min Max and print result:
csvMax = []
csvMin = []

# csvHeaderListLength = len(magHeaderList) 
for i in range(len(magHeaderList)):
 print (magHeaderList[i] + ': ' + str(i))
 strCol = magHeaderList[i]
 csvMax.append(magDataFrame[strCol].max())
 csvMin.append(magDataFrame[strCol].min())
 print ('Max. Value ' + magHeaderList[i] + ' :' + str(csvMax[i]))
 print ('Min. Value ' + magHeaderList[i] + ' :' + str(csvMin[i]))
# Out:
# baltl: 0
# Max. Value baltl :544.1197509765631
# Min. Value baltl :21.6988735198975
# baltlc: 1
# Max. Value baltlc :543.218994140625
# Min. Value baltlc :22.296871185302702
# barom: 2
# Max. Value barom :543.218994140625
# Min. Value barom :22.296871185302702
# baseA: 3
# Max. Value baseA :51035.859375
# Min. Value baseA :50986.76953125
# baseAo: 4
# Max. Value baseAo :51035.87109375
# Min. Value baseAo :50986.76953125
# date: 5
# Max. Value date :2019/12/04
# Min. Value date :2019/10/08
# directn: 6
# Max. Value directn :270
# Min. Value directn :0
# drape: 7
# Max. Value drape :539.487060546875
# Min. Value drape :191.879669189453
# DTMc: 8
# Max. Value DTMc :329.92755126953097
# Min. Value DTMc :-18.0715637207031
# DTMo: 9
# Max. Value DTMo :328.21038818359403
# Min. Value DTMo :-19.9622802734375
# fid10: 10
# Max. Value fid10 :83248.0
# Min. Value fid10 :48077.0
# fiducial: 11
# Max. Value fiducial :83248.0
# Min. Value fiducial :48077.0
# flt: 12
# Max. Value flt :248
# ...
